# %%
import pandas as pd
import numpy as np

# %%
arr=np.array([1,2,3])

# %%
pd.Series(arr)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
d={'a':12,'b':23,'c':10}
d
# Out:
# {'a': 12, 'b': 23, 'c': 10}
